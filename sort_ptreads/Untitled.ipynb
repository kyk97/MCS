# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
f = open('TSE.txt', 'r')
data = f.read()
nums = list(map(float,data.split()))
f.close()
x = np.zeros(0)
y = np.zeros(0)
for i in range(len(nums)): 
    if i % 2 == 1: 
        y = np.append(y, nums[i])
    else :
        x = np.append(x, nums[i])
plt.figure(figsize=(10, 8))
plt.xlabel('P')
plt.ylabel('T')
plt.grid(True)
plt.title('T(P) for n = 1000000, m = 100000')
plt.plot(y, x)
plt.plot(y, x, 'ro')
plt.show()

# %%
f = open('TSE.txt', 'r')
data = f.read()
nums = list(map(float,data.split()))
f.close()
x = np.zeros(0)
y = np.zeros(0)
for i in range(len(nums)): 
    if i % 2 == 1: 
        y = np.append(y, nums[i])
    else:
        if i % 2 == 0:
            x = np.append(x, nums[0] / nums[i])
plt.figure(figsize=(10, 8))
plt.xlabel('P')
plt.ylabel('S')
plt.grid(True)
plt.title('S(P) for n = 1000000, m = 100000')
plt.plot(y, x)
plt.plot(y, x, 'ro')
plt.show()

# %%
f = open('TSE.txt', 'r')
data = f.read()
nums = list(map(float,data.split()))
f.close()
x = np.zeros(0)
y = np.zeros(0)
for i in range(len(nums)): 
    if i % 2 == 1: 
        y = np.append(y, nums[i])
    else :
        x = np.append(x, nums[0] / nums[i] / ((i / 2) + 1))
plt.figure(figsize=(10, 8))
plt.xlabel('P')
plt.ylabel('E')
plt.grid(True)
plt.title('E(P) for n = 1000000, m = 100000')
plt.plot(y, x)
plt.plot(y, x, 'ro')
plt.show()
